# %% [markdown]
# # <Questão N> — <o que se pede>
#
# Dados do enunciado e o que cada um significa. Cada grandeza abaixo aparece três vezes:
# **fórmula**, **substituição** e **resultado** (skill `exercicio-resolvido`).

# %%
import sys
sys.path.append('skills/dominio/exercicio-resolvido/scripts')  # ou copie passo.py para o lado

import sympy as sp
from passo import mostrar

# Domínio declarado: sympy só simplifica direito quando sabe o sinal.
R_S, L_S, w = sp.symbols('R_S L_S omega', positive=True)

# %% [markdown]
# ## <Grandeza 1> — <por que esta fórmula>

# %%
G_S = 1 / R_S
valor_G_S = mostrar('G_S', G_S, {R_S: 75.0}, unidade='S')

# %% [markdown]
# ## Verificação independente
#
# <limite conhecido, caso particular com resposta sabida, ou ordem de grandeza —
# uma por questão, no mínimo.>

# %%
# Ex.: com R_S -> inf, G_S -> 0
print(sp.limit(1 / R_S, R_S, sp.oo))
